# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import sklearn.metrics

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.expand_frame_repr', True)

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %%
athletes = pd.read_csv('data/summerOly_athletes.csv')
hosts = pd.read_csv('data/summerOly_hosts.csv')
medal_counts = pd.read_csv('data/summerOly_medal_counts.csv', encoding='utf-8')
medal_counts = medal_counts.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
programs = pd.read_csv('data/summerOly_programs.csv', encoding='utf-8')
full_medal = pd.read_csv('data/full_medal_data.csv')
LA_events = pd.read_csv('data/LA25_events.csv')

# %%
year_to_country_code = {
    1896: "GRE",  # Athens, Greece
    1900: "FRA",  # Paris, France
    1904: "USA",  # St. Louis, USA
    1908: "GBR",  # London, United Kingdom
    1912: "SWE",  # Stockholm, Sweden
    1916: None,   # Cancelled
    1920: "BEL",  # Antwerp, Belgium
    1924: "FRA",  # Paris, France
    1928: "NED",  # Amsterdam, Netherlands
    1932: "USA",  # Los Angeles, USA
    1936: "GER",  # Berlin, Germany
    1940: None,   # Cancelled
    1944: None,   # Cancelled
    1948: "GBR",  # London, United Kingdom
    1952: "FIN",  # Helsinki, Finland
    1956: "AUS",  # Melbourne, Australia
    1960: "ITA",  # Rome, Italy
    1964: "JPN",  # Tokyo, Japan
    1968: "MEX",  # Mexico City, Mexico
    1972: "GER",  # Munich, Germany
    1976: "CAN",  # Montreal, Canada
    1980: "URS",  # Moscow, Soviet Union
    1984: "USA",  # Los Angeles, USA
    1988: "KOR",  # Seoul, South Korea
    1992: "ESP",  # Barcelona, Spain
    1996: "USA",  # Atlanta, USA
    2000: "AUS",  # Sydney, Australia
    2004: "GRE",  # Athens, Greece
    2008: "CHN",  # Beijing, China
    2012: "GBR",  # London, United Kingdom
    2016: "BRA",  # Rio de Janeiro, Brazil
    2020: "JPN",  # Tokyo, Japan
    2024: "FRA",  # Paris, France
    2028: "USA",  # Los Angeles, USA
    2032: "AUS",  # Brisbane, Australia
}

# %%
hosts['NOC'] = hosts['Year'].map(year_to_country_code)

# %%
NOC = medal_counts['NOC'].str.replace('\xa0','').unique()

# %%
medal_counts_LR = medal_counts

medal_counts_LR = medal_counts_LR.sort_values(by=['NOC', 'Year']).reset_index(drop=True)

medal_counts_LR['Predicted_Medals'] = np.nan

for index, row in medal_counts_LR.iterrows():
    country = row['NOC']
    year = row['Year']
    #print(f"Processing: Country={country}, Year={year}")
    
    # Filter previous years' data for the same country
    historical_data = medal_counts_LR[(medal_counts_LR['NOC'] == country) & (medal_counts_LR['Year'] < year)]
    #print(historical_data)
    
    # Check if there is enough data to train a model
    if len(historical_data) >= 2:  # At least 2 data points needed for Linear Regression
        # Prepare training data
        X_train = (historical_data[['Year']].values - 1900)/4
        y_train = historical_data['Total'].values
        
        # Train the model
        model = LinearRegression()
        model.fit(X_train, y_train)
        
        # Predict the medal count for the current year
        X_test = np.array([[(year-1900)/4]])  # Current year as input
        predicted_medals = model.predict(X_test)[0]
        
        # Store the prediction in the DataFrame
        medal_counts_LR.at[index, 'Predicted_Medals'] = predicted_medals

# %%
# Display the updated DataFrame
medal_counts_LR.iloc[1:10]
# Out:
#    Rank          NOC  Gold  Silver  Bronze  Total  Year  Predicted_Medals
# 1    79  Afghanistan     0       0       1      1  2012               NaN
# 2    80      Albania     0       0       2      2  2024               NaN
# 3    42      Algeria     0       0       2      2  1984               NaN
# 4    34      Algeria     1       0       1      2  1992               NaN
# 5    34      Algeria     2       0       1      3  1996          2.000000
# 6    42      Algeria     1       1       3      5  2000          3.000000
# 7    68      Algeria     0       1       1      2  2008          5.571429
# 8    50      Algeria     1       0       0      1  2012          3.400000
# 9    63      Algeria     0       2       0      2  2016          2.110000

# %%
full_medal.iloc[1:10]
# Out:
#    Rank            NOC  Gold  Silver  Bronze  Total  Year Country Code  \
# 1     2         Greece    10      18      19     47  1896          GRE
# 2     3        Germany     6       5       2     13  1896          GER
# 3     4         France     5       4       2     11  1896          FRA
# 4     5  Great Britain     2       3       2      7  1896          GBR
# 5     6        Hungary     2       1       3      6  1896          HUN
# 6     7        Austria     2       1       2      5  1896          AUT
# 7     8      Australia     2       0       0      2  1896          AUS
# 8     9        Denmark     1       2       3      6  1896          DEN
# 9    10    Switzerland     1       2       0      3  1896          SUI
#
#    Is_Host  Ex-Host  Host Continent  Team Size  Participated Events  \
# 1        1        1               1      148.0                   39
# 2        0        0               1       94.0                   27
# 3        0        0               1       26.0                   18
# 4        0        0               0       25.0                   19
# 5        0        0               1       18.0                   14
# 6        0        0               1        8.0                    8
# 7        0        0               0        5.0                    5
# 8        0        0               1       15.0                   12
# 9        0        0               0        8.0                    5
#
#    Total Events
# 1          43.0
# 2          43.0
# 3          43.0
# 4          43.0
# 5          43.0
# 6          43.0
# 7          43.0
# 8          43.0
# 9          43.0

# %%
medal_counts_LR = full_medal.sort_values(by=['NOC', 'Year']).reset_index(drop=True)

medal_counts_LR['Predicted Medals'] = np.nan
medal_counts_LR['Predicted Proportion of Medals'] = np.nan

coef = []

for index, row in medal_counts_LR.iterrows():
    country = row['NOC']
    year = row['Year']
    
    # Filter previous years' data for the same country
    historical_data = medal_counts_LR[(medal_counts_LR['NOC'] == country) & (medal_counts_LR['Year'] < year)]
    #print(historical_data)
    
    if len(historical_data) >= 2:
        X_train = (historical_data[['Year']].values-1900)/4
        y_train = historical_data['Total'].values
        
        # Train the model
        model = LinearRegression()
        model.fit(X_train, y_train)
        
        # Predict the medal count for the current year
        X_test = np.array([[(year-1900)/4]])  # Current year as input
        predicted_medals = model.predict(X_test)[0]
        
        # Store the prediction in the DataFrame
        medal_counts_LR.at[index, 'Predicted Medals'] = predicted_medals
        medal_counts_LR.at[index, 'Predicted Proportion of Medals'] = predicted_medals/(3* row['Total Events'])

        coef.append(model.coef_)

# %%
# Write a thing that adds a column for relative prediction correctness
medal_counts_LR['Prediction Delta'] = np.nan
delta = abs(medal_counts_LR['Predicted Medals'] - medal_counts_LR['Total'])/medal_counts_LR['Total']
medal_counts_LR['Prediction Delta'] = delta

# %%
nonnan_medal_counts_LR = medal_counts_LR[medal_counts_LR['Predicted Medals'].notnull()]

r2 = sklearn.metrics.r2_score(nonnan_medal_counts_LR['Total'].values, nonnan_medal_counts_LR['Predicted Medals'])
print(r2)

mae = sklearn.metrics.mean_absolute_error(nonnan_medal_counts_LR['Total'].values, nonnan_medal_counts_LR['Predicted Medals'])
print(mse)

rmse = np.sqrt(sklearn.metrics.mean_squared_error(nonnan_medal_counts_LR['Total'].values, nonnan_medal_counts_LR['Predicted Medals']))
print(rmse)
# Out:
# 0.5499999039449266
# 117.83076143887347
# 10.854987859913685

# %%
medal_counts_LR[medal_counts_LR['Year'] == 2020].sort_values(by = ['Prediction Delta'], ascending = False).iloc[:10]
# Out:
#       Rank          NOC  Gold  Silver  Bronze  Total  Year Country Code  \
# 35       0  Afghanistan     0       0       0      0  2020          AFG
# 60       0      Algeria     0       0       0      0  2020          ALG
# 527      0     Cameroon     0       0       0      0  2020          CMR
# 281      0     Barbados     0       0       0      0  2020          BAR
# 3067     0      Uruguay     0       0       0      0  2020          URU
# 3185     0       Zambia     0       0       0      0  2020          ZAM
# 458      0      Burundi     0       0       0      0  2020          BDI
# 816      0     Djibouti     0       0       0      0  2020          DJI
# 753      0       Cyprus     0       0       0      0  2020          CYP
# 709      0   Costa Rica     0       0       0      0  2020          CRC
#
#       Is_Host  Ex-Host  Host Continent  Team Size  Participated Events  \
# 35          0        0               1        5.0                    5
# 60          0        0               0       45.0                   43
# 527         0        0               0       12.0                   12
# 281         0        0               0        9.0                    9
# 3067        0        0               0       11.0                    9
# 3185        0        0               0       31.0                   10
# 458         0        0               0        7.0                    7
# 816         0        0               0        5.0                    5
# 753         0        0               1       23.0                   22
# 709         0        0               0       18.0                   17
#
#       Total Events  Predicted Medals  Predicted Proportion of Medals  \
# 35           339.0          0.443400                        0.000436
# 60           339.0          2.587222                        0.002544
# 527          339.0          0.725275                        0.000713
# 281          339.0          0.151911                        0.000149
# 3067         339.0         -0.150518                       -0.000148
# 3185         339.0          0.135678                        0.000133
# 458          339.0          0.333333                        0.000328
# 816          339.0         -0.125265                       -0.000123
# 753          339.0          0.333333                        0.000328
# 709          339.0          0.469484                        0.000462
#
#       Prediction Delta
# 35                 inf
# 60                 inf
# 527                inf
# 281                inf
# 3067               inf
# 3185               inf
# 458                inf
# 816                inf
# 753                inf
# 709                inf

# %%
mc_MLR = full_medal.sort_values(by=['NOC', 'Year']).reset_index(drop=True)

mc_MLR['Predicted Medals'] = np.nan
mc_MLR['Predicted Proportion of Medals'] = np.nan

for index, row in mc_MLR.iterrows():
    country = row['NOC']
    year = row['Year']
    teamsize = row['Team Size']
    
    # Filter previous years' data for the same country
    historical_data = mc_MLR[(mc_MLR['NOC'] == country) & (mc_MLR['Year'] < year)]
    #print(historical_data)
    
    if len(historical_data) >= 2:
        X_train = historical_data[['Year', 'Team Size']].values
        y_train = historical_data['Total'].values
        
        # Train the model
        model = LinearRegression()
        model.fit(X_train, y_train)
        
        # Predict the medal count for the current year
        X_test = np.array([[year, teamsize]])  # Current year as input
        predicted_medals = model.predict(X_test)[0]
        
        # Store the prediction in the DataFrame
        mc_MLR.at[index, 'Predicted Medals'] = predicted_medals
        mc_MLR.at[index, 'Predicted Proportion of Medals'] = predicted_medals/(3* row['Total Events'])

# %%
nonnan_mc_MLR = mc_MLR[mc_MLR['Predicted Medals'].notnull()]
nonnan_mc_MLR = nonnan_mc_MLR[nonnan_mc_MLR['Predicted Medals'] < 1000]
r2 = sklearn.metrics.r2_score(nonnan_mc_MLR['Total'].values, nonnan_mc_MLR['Predicted Medals'])
print(r2)
# Out:
# 0.8066137366933245

# %%
# Write a thing that adds a column for relative prediction correctness
mc_MLR['Prediction Delta'] = np.nan
delta = abs(mc_MLR['Predicted Medals'] - mc_MLR['Total'])/mc_MLR['Total']
mc_MLR['Prediction Delta'] = delta

# %%
type(mc_MLR[mc_MLR['Year'] == 2024].sum())

#mc_MLR[mc_MLR['Year'] == 2024].sort_values(by = ['Year'], ascending = False)#.iloc[:10]
# Out:
# pandas.core.series.Series

# %%
mc_LR_teamsize = full_medal.sort_values(by=['NOC', 'Year']).reset_index(drop=True)

mc_LR_teamsize['Predicted Medals'] = np.nan
mc_LR_teamsize['Predicted Proportion of Medals'] = np.nan

for index, row in mc_LR_teamsize.iterrows():
    country = row['NOC']
    year = row['Year']
    
    # Filter previous years' data for the same country
    historical_data = mc_LR_teamsize[(mc_LR_teamsize['NOC'] == country) & (mc_LR_teamsize['Year'] < year)]
    #print(historical_data)
    
    if len(historical_data) >= 2:
        X_train = historical_data[['Team Size']].values
        y_train = historical_data['Total'].values
        
        # Train the model
        model = LinearRegression()
        model.fit(X_train, y_train)
        
        # Predict the medal count for the current year
        X_test = np.array([[year]])  # Current year as input
        predicted_medals = model.predict(X_test)[0]
        
        # Store the prediction in the DataFrame
        mc_LR_teamsize.at[index, 'Predicted Medals'] = predicted_medals
        mc_LR_teamsize.at[index, 'Predicted Proportion of Medals'] = predicted_medals/(3* row['Total Events'])

# %%
mc_LR_teamsize['MAE'] = np.nan
mc_LR_teamsize['RSME'] = np.nan

for country, group in mc_LR_teamsize.groupby('NOC'):
    group = group.sort_values(by='Year')
    
    # Features and target
    X = group[['Year', 'Team Size']].values
    y = group['Total'].values

    if len(X) >= 2:
        # Train-test split: Use all but the last row for training, and the last row for testing
        X_train, X_test = X[:-1], X[-1:]
        y_train, y_test = y[:-1], y[-1:]
        
        # Train the model
        model = LinearRegression()
        model.fit(X_train, y_train)
        
        # Predict on the test set
        y_pred = model.predict(X_test)
        
        # Calculate MAE and RMSE
        mae = sklearn.metrics.mean_absolute_error(y_test, y_pred)
        rmse = np.sqrt(sklearn.metrics.mean_squared_error(y_test, y_pred))
        
        # Store the results
        mc_LR_teamsize['MAE'] = mae
        mc_LR_teamsize['RSME'] = rmse

# %%
mc_LR_teamsize.iloc[1:100]
# Out:
#     Rank                  NOC  Gold  Silver  Bronze  Total  Year Country Code  \
# 1      0                  ARU     0       0       0      0  1988          ARU
# 2      0                  ARU     0       0       0      0  1992          ARU
# 3      0                  ARU     0       0       0      0  1996          ARU
# 4      0                  ARU     0       0       0      0  2000          ARU
# 5      0                  ARU     0       0       0      0  2004          ARU
# 6      0                  ARU     0       0       0      0  2008          ARU
# 7      0                  ARU     0       0       0      0  2012          ARU
# 8      0                  ARU     0       0       0      0  2016          ARU
# 9      0                  ARU     0       0       0      0  2020          ARU
# 10     0                  ARU     0       0       0      0  2024          ARU
# 11     0                  ASA     0       0       0      0  1988          ASA
# 12     0                  ASA     0       0       0      0  1992          ASA
# 13     0                  ASA     0       0       0      0  1996          ASA
# 14     0                  ASA     0       0       0      0  2000          ASA
# 15     0                  ASA     0       0       0      0  2004          ASA
# 16     0                  ASA     0       0       0      0  2008          ASA
# 17     0                  ASA     0       0       0      0  2012          ASA
# 18     0                  ASA     0       0       0      0  2016          ASA
# 19     0                  ASA     0       0       0      0  2020          ASA
# 20     0                  ASA     0       0       0      0  2024          ASA
# 21     0          Afghanistan     0       0       0      0  1936          AFG
# 22     0          Afghanistan     0       0       0      0  1948          AFG
# 23     0          Afghanistan     0       0       0      0  1956          AFG
# 24     0          Afghanistan     0       0       0      0  1960          AFG
# 25     0          Afghanistan     0       0       0      0  1964          AFG
# 26     0          Afghanistan     0       0       0      0  1968          AFG
# 27     0          Afghanistan     0       0       0      0  1972          AFG
# 28     0          Afghanistan     0       0       0      0  1980          AFG
# 29     0          Afghanistan     0       0       0      0  1988          AFG
# 30     0          Afghanistan     0       0       0      0  1996          AFG
# 31     0          Afghanistan     0       0       0      0  2004          AFG
# 32    82          Afghanistan     0       0       1      1  2008          AFG
# 33    79          Afghanistan     0       0       1      1  2012          AFG
# 34     0          Afghanistan     0       0       0      0  2016          AFG
# 35     0          Afghanistan     0       0       0      0  2020          AFG
# 36     0          Afghanistan     0       0       0      0  2024          AFG
# 37     0              Albania     0       0       0      0  1972          ALB
# 38     0              Albania     0       0       0      0  1992          ALB
# 39     0              Albania     0       0       0      0  1996          ALB
# 40     0              Albania     0       0       0      0  2000          ALB
# 41     0              Albania     0       0       0      0  2004          ALB
# 42     0              Albania     0       0       0      0  2008          ALB
# 43     0              Albania     0       0       0      0  2012          ALB
# 44     0              Albania     0       0       0      0  2016          ALB
# 45     0              Albania     0       0       0      0  2020          ALB
# 46    80              Albania     0       0       2      2  2024          ALB
# 47     0              Algeria     0       0       0      0  1964          ALG
# 48     0              Algeria     0       0       0      0  1968          ALG
# 49     0              Algeria     0       0       0      0  1972          ALG
# 50     0              Algeria     0       0       0      0  1980          ALG
# 51    42              Algeria     0       0       2      2  1984          ALG
# 52     0              Algeria     0       0       0      0  1988          ALG
# 53    34              Algeria     1       0       1      2  1992          ALG
# 54    34              Algeria     2       0       1      3  1996          ALG
# 55    42              Algeria     1       1       3      5  2000          ALG
# 56     0              Algeria     0       0       0      0  2004          ALG
# 57    68              Algeria     0       1       1      2  2008          ALG
# 58    50              Algeria     1       0       0      1  2012          ALG
# 59    63              Algeria     0       2       0      2  2016          ALG
# 60     0              Algeria     0       0       0      0  2020          ALG
# 61    39              Algeria     2       0       1      3  2024          ALG
# 62     0              Andorra     0       0       0      0  1976          AND
# 63     0              Andorra     0       0       0      0  1980          AND
# 64     0              Andorra     0       0       0      0  1984          AND
# 65     0              Andorra     0       0       0      0  1988          AND
# 66     0              Andorra     0       0       0      0  1992          AND
# 67     0              Andorra     0       0       0      0  1996          AND
# 68     0              Andorra     0       0       0      0  2000          AND
# 69     0              Andorra     0       0       0      0  2004          AND
# 70     0              Andorra     0       0       0      0  2008          AND
# 71     0              Andorra     0       0       0      0  2012          AND
# 72     0              Andorra     0       0       0      0  2016          AND
# 73     0              Andorra     0       0       0      0  2020          AND
# 74     0              Andorra     0       0       0      0  2024          AND
# 75     0               Angola     0       0       0      0  1980          ANG
# 76     0               Angola     0       0       0      0  1988          ANG
# 77     0               Angola     0       0       0      0  1992          ANG
# 78     0               Angola     0       0       0      0  1996          ANG
# 79     0               Angola     0       0       0      0  2000          ANG
# 80     0               Angola     0       0       0      0  2004          ANG
# 81     0               Angola     0       0       0      0  2008          ANG
# 82     0               Angola     0       0       0      0  2012          ANG
# 83     0               Angola     0       0       0      0  2016          ANG
# 84     0               Angola     0       0       0      0  2020          ANG
# 85     0               Angola     0       0       0      0  2024          ANG
# 86     0  Antigua and Barbuda     0       0       0      0  1976          ANT
# 87     0  Antigua and Barbuda     0       0       0      0  1984          ANT
# 88     0  Antigua and Barbuda     0       0       0      0  1988          ANT
# 89     0  Antigua and Barbuda     0       0       0      0  1992          ANT
# 90     0  Antigua and Barbuda     0       0       0      0  1996          ANT
# 91     0  Antigua and Barbuda     0       0       0      0  2000          ANT
# 92     0  Antigua and Barbuda     0       0       0      0  2004          ANT
# 93     0  Antigua and Barbuda     0       0       0      0  2008          ANT
# 94     0  Antigua and Barbuda     0       0       0      0  2012          ANT
# 95     0  Antigua and Barbuda     0       0       0      0  2016          ANT
# 96     0  Antigua and Barbuda     0       0       0      0  2020          ANT
# 97     0  Antigua and Barbuda     0       0       0      0  2024          ANT
# 98     0            Argentina     0       0       0      0  1900          ARG
# 99     0            Argentina     0       0       0      0  1908          ARG
#
#     Is_Host  Ex-Host  Host Continent  Team Size  Participated Events  \
# 1         0        0               0       12.0                   10
# 2         0        0               0        5.0                    4
# 3         0        0               1        3.0                    3
# 4         0        0               0        5.0                    5
# 5         0        0               0        4.0                    4
# 6         0        0               0        2.0                    2
# 7         0        0               0        4.0                    4
# 8         0        0               0        7.0                    6
# 9         0        0               0        4.0                    4
# 10        0        0               0        7.0                    7
# 11        0        0               0        6.0                    6
# 12        0        0               1        3.0                    3
# 13        0        0               0        7.0                    6
# 14        0        0               0        4.0                    4
# 15        0        0               0        3.0                    3
# 16        0        0               0        4.0                    4
# 17        0        0               1        4.0                    4
# 18        0        0               0        4.0                    4
# 19        0        0               0        6.0                    5
# 20        0        0               0        2.0                    2
# 21        0        0               0       16.0                    4
# 22        0        0               0       25.0                    2
# 23        0        0               0       12.0                    1
# 24        0        0               0       16.0                   13
# 25        0        0               1        8.0                    8
# 26        0        0               0        5.0                    5
# 27        0        0               0        8.0                    8
# 28        0        0               0       11.0                   11
# 29        0        0               1        5.0                    5
# 30        0        0               0        2.0                    2
# 31        0        0               0        5.0                    5
# 32        0        0               1        4.0                    4
# 33        0        0               0        6.0                    6
# 34        0        0               0        3.0                    3
# 35        0        0               1        5.0                    5
# 36        0        0               0        7.0                    6
# 37        0        0               1        5.0                    3
# 38        0        0               0        9.0                    8
# 39        0        0               0        9.0                    7
# 40        0        0               0        5.0                    5
# 41        0        0               1        7.0                    7
# 42        0        0               0       12.0                   12
# 43        0        0               0       10.0                    9
# 44        0        0               0        6.0                    6
# 45        0        0               0       10.0                   10
# 46        0        0               1        9.0                    9
# 47        0        0               0        7.0                    7
# 48        0        0               0        9.0                    9
# 49        0        0               0        7.0                    5
# 50        0        0               0       63.0                   28
# 51        0        0               0       33.0                   17
# 52        0        0               0       45.0                   29
# 53        0        0               0       36.0                   27
# 54        0        0               0       47.0                   29
# 55        0        0               0       51.0                   42
# 56        0        0               0       71.0                   57
# 57        0        0               0       57.0                   44
# 58        0        0               0       39.0                   29
# 59        0        0               0       74.0                   48
# 60        0        0               0       45.0                   43
# 61        0        0               0       55.0                   47
# 62        0        0               0        3.0                    2
# 63        0        0               1        2.0                    1
# 64        0        0               0        2.0                    1
# 65        0        0               0        4.0                    3
# 66        0        0               0        8.0                    5
# 67        0        0               0        8.0                    7
# 68        0        0               0        5.0                    5
# 69        0        0               1        6.0                    6
# 70        0        0               0        5.0                    5
# 71        0        0               0        6.0                    6
# 72        0        0               0        4.0                    4
# 73        0        0               0        3.0                    3
# 74        0        0               1        4.0                    4
# 75        0        0               0       17.0                   14
# 76        0        0               0       33.0                   27
# 77        0        0               0       33.0                   21
# 78        0        0               0       30.0                    8
# 79        0        0               0       30.0                    7
# 80        0        0               0       30.0                    5
# 81        0        0               0       33.0                    8
# 82        0        0               0       35.0                   10
# 83        0        0               0       26.0                   10
# 84        0        0               0       20.0                    6
# 85        0        0               0       26.0                   10
# 86        0        0               1       17.0                   11
# 87        0        0               1       27.0                   17
# 88        0        0               0       25.0                   19
# 89        0        0               0       18.0                   15
# 90        0        0               1       19.0                    9
# 91        0        0               0        4.0                    4
# 92        0        0               0        5.0                    5
# 93        0        0               0        5.0                    5
# 94        0        0               0        4.0                    4
# 95        0        0               0        9.0                    5
# 96        0        0               0        6.0                    6
# 97        0        0               0        5.0                    5
# 98        0        0               0        1.0                    1
# 99        0        0               0        1.0                    1
#
#     Total Events  Predicted Medals  Predicted Proportion of Medals       MAE  \
# 1          237.0               NaN                             NaN  1.165778
# 2          257.0               NaN                             NaN  1.165778
# 3          271.0          0.000000                        0.000000  1.165778
# 4          300.0          0.000000                        0.000000  1.165778
# 5          301.0          0.000000                        0.000000  1.165778
# 6          302.0          0.000000                        0.000000  1.165778
# 7          302.0          0.000000                        0.000000  1.165778
# 8          306.0          0.000000                        0.000000  1.165778
# 9          339.0          0.000000                        0.000000  1.165778
