# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/full_medal_data.csv')
sex = pd.read_csv('data/summerOly_athletes.csv')[['NOC', 'Year', 'Sex']].sort_values(by=['NOC', 'Year']).reset_index(drop=True)
sex = sex.groupby(['NOC', 'Year'])['Sex'].apply(lambda x: (x == 'M').mean()).reset_index()
events = pd.read_csv('data/summerOly_programs.csv').loc[71].reset_index()[4:].rename(columns={'index': 'Year', 71: 'Events'}).astype({'Events': 'int32'})
events['Year'] = events['Year'].str.replace('*', '')
events['Difference'] = events['Events'].diff().fillna(0)
events = events.astype({'Year': 'int32'}).reset_index(drop=True)

for i in range(len(events)):
    df.loc[df['Year'] == events.loc[i, 'Year'], 'Events Difference'] = events.loc[i, 'Difference']

df = df.sort_values(by=['Country Code', 'Year']).reset_index(drop=True)
for i in range(len(df)):
    sex_country_yr = sex[(sex['NOC'] == df.loc[i,'Country Code']) & (sex['Year'] == df.loc[i,'Year'])]
    if len(sex_country_yr) == 0:
        continue
    df.loc[i,'Sex'] = sex_country_yr.iloc[0, 2]
df = df.dropna().reset_index(drop=True)
df
# Out:
#       Rank          NOC  Gold  Silver  Bronze  Total  Year Country Code  \
# 0        0  Afghanistan     0       0       0      0  1936          AFG
# 1        0  Afghanistan     0       0       0      0  1948          AFG
# 2        0  Afghanistan     0       0       0      0  1956          AFG
# 3        0  Afghanistan     0       0       0      0  1960          AFG
# 4        0  Afghanistan     0       0       0      0  1964          AFG
# ...    ...          ...   ...     ...     ...    ...   ...          ...
# 3195    38     Zimbabwe     1       3       0      4  2008          ZIM
# 3196     0     Zimbabwe     0       0       0      0  2012          ZIM
# 3197     0     Zimbabwe     0       0       0      0  2016          ZIM
# 3198     0     Zimbabwe     0       0       0      0  2020          ZIM
# 3199     0     Zimbabwe     0       0       0      0  2024          ZIM
#
#       Is_Host  Ex-Host  Host Continent  Team Size  Participated Events  \
# 0           0        0               0      16.00                    4
# 1           0        0               0      25.00                    2
# 2           0        0               0      12.00                    1
# 3           0        0               0      16.00                   13
# 4           0        0               1       8.00                    8
# ...       ...      ...             ...        ...                  ...
# 3195        0        0               0      16.00                   15
# 3196        0        0               0       9.00                    8
# 3197        0        0               0      31.00                   13
# 3198        0        0               0       5.00                    5
# 3199        0        0               0       7.00                    6
#
#       Total Events  Events Difference  Sex
# 0           129.00              12.00 1.00
# 1           136.00               7.00 1.00
# 2           151.00               2.00 1.00
# 3           150.00              -1.00 1.00
# 4           163.00              13.00 1.00
# ...            ...                ...  ...
# 3195        302.00               1.00 0.50
# 3196        302.00               0.00 0.44
# 3197        306.00               4.00 0.29
# 3198        339.00              33.00 0.80
# 3199        329.00             -10.00 0.71
#
# [3200 rows x 16 columns]

# %%
countries = df['Country Code'].unique()

rows = []
for country_name in countries:
    country = df[df['Country Code'] == country_name][['Country Code', 'Year', 'Total', 'Team Size', 'Participated Events', 'Sex', 'Events Difference']]
    
    first_medal_yr = country[country['Total'] > 0]
    if len(first_medal_yr) == 0:
        continue

    first_medal_yr = first_medal_yr.iloc[0,1]

    first_medal = df[(df['Year'] == first_medal_yr) & (df['Country Code'] == country_name)]
    no_medals = df[(df['Year'] < first_medal_yr) & (df['Country Code'] == country_name)]

    rows.append([*first_medal.iloc[0].loc[['Team Size', 'Participated Events', 'Sex', 'Events Difference']], 1])
    for i in range(len(no_medals)):
        rows.append([*no_medals.iloc[i].loc[['Team Size', 'Participated Events', 'Sex', 'Events Difference']], 0])

# %%
first_medals = pd.DataFrame(rows, columns=['Team Size', 'Participated Events', 'Sex', 'Events Difference', 'First Medal'])
plt.scatter(first_medals['Events Difference'], first_medals['First Medal'])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X = first_medals[['Team Size', 'Participated Events', 'Sex', 'Events Difference']].to_numpy()
y = first_medals[['First Medal']].to_numpy().flatten()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
reg = LogisticRegression().fit(X_train, y_train)

score = reg.score(X_test, y_test)
print(score)
# Out:
# 0.7619047619047619

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [00:01<00:00, 21.55it/s]
# [LightGBM] [Info] Number of positive: 113, number of negative: 326
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000107 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 172
# [LightGBM] [Info] Number of data points in the train set: 439, number of used features: 4
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.257403 -> initscore=-1.059510
# [LightGBM] [Info] Start training from score -1.059510
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.80               0.72     0.72      0.79
# RandomForestClassifier             0.80               0.70     0.70      0.79
# DecisionTreeClassifier             0.78               0.70     0.70      0.77
# KNeighborsClassifier               0.82               0.70     0.70      0.79
# BaggingClassifier                  0.79               0.69     0.69      0.77
# ExtraTreesClassifier               0.76               0.68     0.68      0.75
# BernoulliNB                        0.73               0.68     0.68      0.73
# NearestCentroid                    0.75               0.67     0.67      0.74
# ExtraTreeClassifier                0.73               0.66     0.66      0.73
# QuadraticDiscriminantAnalysis      0.78               0.66     0.66      0.76
# PassiveAggressiveClassifier        0.76               0.66     0.66      0.75
# GaussianNB                         0.78               0.65     0.65      0.75
# AdaBoostClassifier                 0.76               0.64     0.64      0.73
# CalibratedClassifierCV             0.79               0.64     0.64      0.75
# SVC                                0.79               0.63     0.63      0.74
# LogisticRegression                 0.78               0.63     0.63      0.74
# LinearSVC                          0.77               0.62     0.62      0.73
# NuSVC                              0.78               0.62     0.62      0.73
# LabelSpreading                     0.74               0.61     0.61      0.71
# LabelPropagation                   0.74               0.61     0.61      0.71
# LinearDiscriminantAnalysis         0.76               0.58     0.58      0.69
# SGDClassifier                      0.72               0.58     0.58      0.69
# Perceptron                         0.60               0.58     0.58      0.62
# RidgeClassifier                    0.75               0.56     0.56      0.67
# RidgeClassifierCV                  0.75               0.56     0.56      0.67
# DummyClassifier                    0.71               0.50     0.50      0.60
#
#                                Time Taken
# Model
# LGBMClassifier                       0.16
# RandomForestClassifier               0.09
# DecisionTreeClassifier               0.00
# KNeighborsClassifier                 0.01
# BaggingClassifier                    0.02
# ExtraTreesClassifier                 0.14
# BernoulliNB                          0.00
# NearestCentroid                      0.03
# ExtraTreeClassifier                  0.00
# QuadraticDiscriminantAnalysis        0.01
# PassiveAggressiveClassifier          0.01
# GaussianNB                           0.01
# AdaBoostClassifier                   0.10
# CalibratedClassifierCV               0.02
# SVC                                  0.01
# LogisticRegression                   0.01
# LinearSVC                            0.01
# NuSVC                                0.06
# LabelSpreading                       0.58
# LabelPropagation                     0.04
# LinearDiscriminantAnalysis           0.01
# SGDClassifier                        0.00
# Perceptron                           0.01
# RidgeClassifier                      0.01
# RidgeClassifierCV                    0.01
# DummyClassifier                      0.00
