# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/combined_data.csv')
data
# Out:
#                          Name Sex               Team  NOC  Year         City  \
# 0                   A Dijiang   M              China  CHN  1992    Barcelona
# 1                    A Lamusi   M              China  CHN  2012       London
# 2                 Gunnar Aaby   M            Denmark  DEN  1920    Antwerpen
# 3                 Edgar Aabye   M     Denmark/Sweden  DEN  1900        Paris
# 4       Cornelia (-strannood)   F        Netherlands  NED  1932  Los Angeles
# ...                       ...  ..                ...  ...   ...          ...
# 252560             Sefora Ada   F  Equatorial Guinea  GEQ  2024        Paris
# 252561        Emanuela Liuzzi   F              Italy  ITA  2024        Paris
# 252562           Isayah Boers   M        Netherlands  NED  2024        Paris
# 252563            Kevin Staut   M             France  FRA  2024        Paris
# 252564        Charlie Carvell   M      Great Britain  GBR  2024        Paris
#
# ...

# %%
data = data.sort_values(['Name', 'Year'])
names = data['Name'].unique()

for name in names[90:]:
    events = data[data['Name'] == name]
    events.loc[:, 'Medals Earned'] = events.loc[:, 'Total Medals'].diff()
    display(events)
    break
# Out:
# /var/folders/5c/216t7l5x1_j3zsn2fm8z7s180000gn/T/ipykernel_57978/1474373944.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   events.loc[:, 'Medals Earned'] = events.loc[:, 'Total Medals'].diff()
#                      Name Sex     Team  NOC  Year         City    Sport  \
# 111521  Aage Leidersdorff   M  Denmark  DEN  1932  Los Angeles  Fencing
# 111522  Aage Leidersdorff   M  Denmark  DEN  1932  Los Angeles  Fencing
# 111523  Aage Leidersdorff   M  Denmark  DEN  1932  Los Angeles  Fencing
# 111524  Aage Leidersdorff   M  Denmark  DEN  1932  Los Angeles  Fencing
# 111525  Aage Leidersdorff   M  Denmark  DEN  1932  Los Angeles  Fencing
# 111526  Aage Leidersdorff   M  Denmark  DEN  1936       Berlin  Fencing
# ...
